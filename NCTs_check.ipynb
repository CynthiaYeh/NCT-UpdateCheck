# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None)
from datetime import datetime
import numpy as np
import requests
requests.packages.urllib3.disable_warnings()
from bs4 import BeautifulSoup
import time #Sleep between downloads

# %%
# Read files and subset the dataset
refs = pd.read_csv("Source database.csv", encoding = "utf-8")
refs_nct = refs[(refs.database == "yes") & (refs.search == "clinicaltrials.gov")]

# %%
### Temp ###
# refs_nct = refs_nct.replace(to_replace=r'NCT00147641', value='NCT00159861', regex=True)

### Obsolete NCT ID, change it to the new one, but join back with the source.number

# %%
# Change search.date to datetime
refs_nct["search.date"] = [datetime.strptime(d, '%Y-%m-%d') for d in refs_nct["search.date"]]
# refs_nct["search.date"] = [datetime.strptime(d, '%m/%d/%Y') for d in refs_nct["search.date"]]

### Set time to 00:00?

# %%
def parsed_html(url, timeout=2000, verify=False, sleep_time=5):
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.1.2222.33 Safari/537.36",
        "Accept-Encoding": "*",
        "Connection": "keep-alive"}
    
    # Download the context from the url
    page = requests.get(url, timeout=20, verify=False, headers = headers)
    
    # Check if HTTP status code is anything other than "ok"
    if page.status_code != 200:
        return None
    
    # Grab the raw HTML of the result
    raw_html = page.text
    
    # Use pd.read_html to convert it to a pd.dataframe
    df = pd.read_html(raw_html)[0]
    
    # We have added a default 1 sec sleep
    time.sleep(sleep_time)
    
    # Return the parsed results
    return df

# %%
# Loop over the subset to find the last change date for outcome measures on clinicatrials.gov
last_update = []

for i in refs_nct.url:
    
    # replace /show/ to /history/ in urls
    i = i.replace("show", "history")
    print(i)
    
    df_oc = parsed_html(i)
    
    #drop all na rows
    df_oc = df_oc.dropna(how = "all")
    
    # Find the most recent change for outcome measures
#     print(df[df["Changes"].str.contains("Outcome Measures")])
    df_last_oc = df_oc[df_oc["Changes"].str.contains("Outcome Measures")].tail(1)
    
    # if df does not contain outcome measures changes, print the message
    if df_last_oc.empty:
        print(f"{i} does not change outcomes before")
        last_update.append(np.nan)
    
    else:
        d_oc = df_last_oc["Submitted Date"].item()
    
        # Transform last date update to desired format (mm/dd/yyyy)
        update_time = datetime.strptime(d_oc, "%B %d, %Y")
        update_time_str = datetime.strftime(update_time, "%Y-%m-%d")
        print(update_time_str)

        # Save as a list
        last_update.append(update_time)
# Out:
# https://clinicaltrials.gov/ct2/history/NCT03317496
# 2022-05-26
# https://clinicaltrials.gov/ct2/history/NCT03689855
# 2022-07-14
# https://clinicaltrials.gov/ct2/history/NCT04089553
# 2022-07-29
# https://clinicaltrials.gov/ct2/history/NCT03132636
# 2022-06-30
# https://clinicaltrials.gov/ct2/history/NCT01844505
# 2019-08-21
# https://clinicaltrials.gov/ct2/history/NCT02387996
# 2022-10-11
# https://clinicaltrials.gov/ct2/history/NCT02256436
# 2021-08-23
# https://clinicaltrials.gov/ct2/history/NCT01903993
# 2019-09-10
# https://clinicaltrials.gov/ct2/history/NCT01668784
# 2022-07-15
# https://clinicaltrials.gov/ct2/history/NCT02572167
# 2022-10-17
# https://clinicaltrials.gov/ct2/history/NCT02038946
# 2021-12-13
# https://clinicaltrials.gov/ct2/history/NCT02105636
# 2022-09-06
# https://clinicaltrials.gov/ct2/history/NCT01642004
# 2022-11-22
# 2020-11-17
# https://clinicaltrials.gov/ct2/history/NCT02639065
# 2022-05-05
# https://clinicaltrials.gov/ct2/history/NCT03373760
# 2021-12-22
# https://clinicaltrials.gov/ct2/history/NCT03074318
# 2022-04-27
# https://clinicaltrials.gov/ct2/history/NCT03717155
# 2022-05-13
# https://clinicaltrials.gov/ct2/history/NCT03204812
# 2022-05-02
# https://clinicaltrials.gov/ct2/history/NCT02766335
# 2021-12-01
# https://clinicaltrials.gov/ct2/history/NCT03637491
# 2021-12-28
# https://clinicaltrials.gov/ct2/history/NCT03057106
# 2022-02-08
# https://clinicaltrials.gov/ct2/history/NCT03434379
# 2021-10-07
# https://clinicaltrials.gov/ct2/history/NCT02584634
# 2022-01-13
# https://clinicaltrials.gov/ct2/history/NCT02794883
# 2022-03-17
# https://clinicaltrials.gov/ct2/history/NCT02764333
# https://clinicaltrials.gov/ct2/history/NCT02764333 does not change outcomes before
# https://clinicaltrials.gov/ct2/history/NCT03726879
# 2022-03-24
# https://clinicaltrials.gov/ct2/history/NCT03050814
# 2021-11-09
# https://clinicaltrials.gov/ct2/history/NCT03164616
# 2022-03-11
# https://clinicaltrials.gov/ct2/history/NCT02542293
# 2022-04-29
# https://clinicaltrials.gov/ct2/history/NCT03628716
# 2022-03-31
# https://clinicaltrials.gov/ct2/history/NCT03679767
# 2022-04-13
# https://clinicaltrials.gov/ct2/history/NCT02499328
# 2021-10-27
# https://clinicaltrials.gov/ct2/history/NCT03367819
# 2022-04-21
# https://clinicaltrials.gov/ct2/history/NCT02325739
# 2020-11-21
# https://clinicaltrials.gov/ct2/history/NCT02998528
# 2022-08-31
# https://clinicaltrials.gov/ct2/history/NCT02901899
# 2021-04-16

# %%
# Loop over the subset to find the last update date on clinicatrials.gov
last_post = []

for i in refs_nct.url:
    
    # replace /show/ to /archive/
    i = i.replace("show", "archive")
#     print(i)
    
    df = pd.read_html(i)[0]
    
# Get the last row value (assuming the last row is referred to last update posted)
#     print(df.iloc[-1])

    # Transform last date update to desired format (mm/dd/yyyy)
    d = str(df[1].iloc[-1])
    post_time = datetime.strptime(d, "%B %d, %Y")
    post_time_str = datetime.strftime(post_time, "%Y-%m-%d")
    print(post_time_str)

    # Save as a list
    last_post.append(post_time)
# Out:
# 2023-02-08
# 2022-08-11
# 2023-01-13
# 2022-07-26
# 2022-10-12
# 2022-11-01
# 2021-09-20
# 2019-10-02
# 2022-08-09
# 2022-11-08
# 2022-01-04
# 2022-10-05
# 2022-12-28
# 2020-03-31
# 2023-01-25
# 2019-01-03
# 2023-02-16
# 2019-09-17
# 2023-01-11
# 2022-12-08
# 2022-03-29
# 2022-12-07
# 2019-01-08
# 2020-11-24
# 2022-12-14
# 2022-10-04
# 2019-12-23
# 2023-01-30
# 2021-08-09
# 2022-12-07
# 2015-02-20
# 2021-02-17
# 2022-07-26
# 2020-12-17
# 2021-10-12
# 2018-08-02
# 2020-12-22
# 2022-01-31
# 2018-11-01
# 2022-12-06
# 2020-05-13
# 2023-01-23
# 2019-08-01
# 2023-01-19
# 2020-06-02
# 2022-07-12
# 2022-11-08
# 2019-02-15
# 2020-09-29
# 2022-09-13
refs_nct.insert(3, "nct_update_needed", np.nan)
refs_nct.insert(4, "last_update_posted", last_post)
refs_nct.nct_update_needed = refs_nct["last_outcome_change"] > refs_nct["search.date"]
refs_nct["last_outcome_change"] = [datetime.strftime(d, "%Y-%m-%d") if pd.notnull(d) else "" for d in refs_nct["last_outcome_change"]]
refs_nct["last_update_posted"] = [datetime.strftime(d, "%Y-%m-%d") if pd.notnull(d) else "" for d in refs_nct["last_update_posted"]]

# %%
refs_merge = pd.merge(refs, refs_nct[["source.number", "last_outcome_change", "nct_update_needed", "last_update_posted"]], how = "left", on = "source.number")

# %%
# Convert nan to ""
refs_merge["last_outcome_change"] = refs_merge["last_outcome_change"].replace(np.nan, "")
refs_merge["search.date"] = refs_merge["search.date"].replace(np.nan, "")
refs_merge["last_update_posted"] = refs_merge["last_update_posted"].replace(np.nan, "")

# %%
# convert date to string
for i in range(len(refs_merge)):
    refs_merge["search.date"][i] = str("=\"") + refs_merge["search.date"][i] + str("\"")
    refs_merge["last_outcome_change"][i] = str("=\"") + refs_merge["last_outcome_change"][i] + str("\"")
    refs_merge["last_update_posted"][i] = str("=\"") + refs_merge["last_update_posted"][i] + str("\"")

# for i,j in zip(refs_merge["search.date"],refs_merge["last_nct_update"]):
#     i = str("=\"") + i + str("\"")
#     j = str("=\"") + j + str("\"")

# %%
refs_merge
# Out:
#                   search    search.date  \
# 0                 pubmed  ="2022-09-08"
# 1                 pubmed  ="2022-09-08"
# 2                 pubmed  ="2022-09-08"
# 3                 pubmed  ="2022-09-08"
# 4                 pubmed  ="2022-09-08"
# ...                  ...            ...
# 2174              pubmed  ="2022-09-08"
# 2175  clinicaltrials.gov  ="2022-09-08"
# 2176  clinicaltrials.gov  ="2022-09-08"
# 2177  clinicaltrials.gov  ="2022-09-08"
# 2178     cross-reference  ="2022-09-08"
#
#                                                   url  source.number  \
# 0        https://www.ncbi.nlm.nih.gov/pubmed/33818208       33818208
# 1        https://www.ncbi.nlm.nih.gov/pubmed/34393061       34393061
# 2        https://www.ncbi.nlm.nih.gov/pubmed/34456145       34456145
# 3        https://www.ncbi.nlm.nih.gov/pubmed/34470722       34470722
# 4        https://www.ncbi.nlm.nih.gov/pubmed/34489161       34489161
# ...                                               ...            ...
# 2174     https://www.ncbi.nlm.nih.gov/pubmed/31435660       31435660
# 2175  https://clinicaltrials.gov/ct2/show/NCT02325739            388
# 2176  https://clinicaltrials.gov/ct2/show/NCT02998528            389
# 2177  https://clinicaltrials.gov/ct2/show/NCT02901899            390
# 2178      http://www.ncbi.nlm.nih.gov/pubmed/34358724       34358724
#
#                                                 authors  publication.year  \
# 0     Bassanelli M, Ricciuti B, Giannarelli D, Cecer...            2022.0
# 1     Remon J, Girard N, Novello S, de Castro J, Big...            2022.0
# 2     Wong DJ, Bauer TM, Gordon MS, Bene-Tchaleu F, ...            2022.0
# 3     Belluomini L, Dionisi V, Palmerio S, Vincenzi ...            2022.0
# 4     De Ruysscher D, Ramalingam S, Urbanic J, Gerbe...            2022.0
# ...                                                 ...               ...
# 2174  Aguilar EJ, Ricciuti B, Gainor JF, Kehl KL, Kr...            2019.0
# 2175                                           Novartis            2020.0
# 2176                                                BMS            2022.0
# 2177                            Northwestern University            2021.0
# 2178  Yang Y, Sun J, Wang Z, Fang J, Yu Q, Han B, Ca...            2021.0
#
#                                                   title             journal  \
# 0     Systemic effect of radiotherapy before or afte...              Tumori
# 1     PECATI: A Multicentric, Open-Label, Single-Arm...    Clin Lung Cancer
# 2     Safety and Clinical Activity of Atezolizumab P...    Clin Lung Cancer
# 3     Study Design and Rationale for Espera Trial: A...    Clin Lung Cancer
# 4     CheckMate 73L: A Phase 3 Study Comparing Nivol...    Clin Lung Cancer
# ...                                                 ...                 ...
# 2174  Outcomes to first-line pembrolizumab in patien...           Ann Oncol
# 2175  A Phase I/II, Multicenter, Open-label Study of...  clinicaltrials.gov
# 2176  Randomized, OpenLabel, Phase 3 Trial of Nivolu...  clinicaltrials.gov
# 2177  An Open Label Phase II Trial of Guadecitabine ...  clinicaltrials.gov
# 2178  Updated Overall Survival Data and Predictive B...      J Thorac Oncol
#
#      volume      pages  ...        control n.study n.arm comment location  \
# 0       108    250-257  ...            NaN     NaN   NaN     NaN      NaN
# 1        23  e243-e246  ...            NaN      43     1     NaN      NaN
# 2        23    273-281  ...     no control      23     1     NaN      NaN
# 3        23  e269-e272  ...  pembrolizumab     NaN     2     NaN      NaN
# 4        23  e264-e268  ...            NaN     888     3     NaN      NaN
# ...     ...        ...  ...            ...     ...   ...     ...      ...
# 2174     30  1653-1659  ...     no control     187     1     NaN      NaN
# 2175    NaN        NaN  ...         FGF401     172     7     NaN      NaN
# 2176    NaN        NaN  ...   chemotherapy     358     2     NaN      NaN
# 2177    NaN        NaN  ...     no control      45     1     NaN      NaN
# 2178     16  2109-2120  ...     pemetrexed     397     2     NaN      NaN
#
#           e.copy database last_outcome_change nct_update_needed  \
# 0            NaN       no                 =""               NaN
# 1       received       no                 =""               NaN
# 2            yes      yes                 =""               NaN
# 3       received       no                 =""               NaN
# 4            yes       no                 =""               NaN
# ...          ...      ...                 ...               ...
# 2174         yes      yes                 =""               NaN
# 2175         yes      yes       ="2020-11-21"             False
# 2176         yes      yes       ="2022-08-31"             False
# 2177         yes      yes       ="2021-04-16"             False
# 2178  downloaded      yes                 =""               NaN
#
#      last_update_posted
# 0                   =""
# 1                   =""
# 2                   =""
# 3                   =""
# 4                   =""
# ...                 ...
# 2174                =""
# 2175      ="2020-12-17"
# 2176      ="2023-02-10"
# 2177      ="2021-05-12"
# 2178                =""
#
# [2179 rows x 28 columns]

# %%
refs_merge.to_csv("NCTs update check.csv", index = False, encoding = "utf-8")

# %%
url = "https://clinicaltrials.gov/ct2/archive/NCT00795639"
df = pd.read_html(url)[0]
print(df)

# Get the last row value (assuming the last row is referred to last update posted)
print(df[1].iloc[-1])

# Transform last date update to desired format (mm/dd/yyyy)
d = str(df[1].iloc[-1])
update_time = datetime.strptime(d, "%B %d, %Y")
# datetime.strftime(update_time, "%Y-%m-%d")

print(update_time)

# %%
url = "https://clinicaltrials.gov/ct2/history/NCT01560624"
df = pd.read_html(url)[0]

# %%
# Find the most recent change for outcome measures 
df.dropna(how = "all")
df[df["Changes"].str.contains("Outcome Measures")].tail(1)
df_last["Submitted Date"].item()
